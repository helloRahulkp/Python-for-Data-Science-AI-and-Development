# %% [markdown]
# Tuples
# Tuples are immutable series of connected values

# %%
tuple01 = ("disco", 10,1.2)
type(tuple01)
# Out:
# tuple

# %%
tuple01[0]
# Out:
# 'disco'

# %%
tuple01[-1]
# Out:
# 1.2

# %%
len(tuple01)
# Out:
# 3

# %%
rating = (0, 1, 20, 3, 4, 5)
rating1 = rating
print(rating1)
# Out:
# (0, 1, 20, 3, 4, 5)

# %%
rating[0] = 10
print(rating)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 rating[0] = 10
#       2 print(rating)
#
# TypeError: 'tuple' object does not support item assignment

# %%
sorted(rating)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sorted(rating)
#
# NameError: name 'rating' is not defined

# %%
l = ["Mj", 10, 1.2]
print(type(l))
# Out:
# <class 'list'>

# %%
l[0]=200
print(l)
# Out:
# [200, 10, 1.2]
