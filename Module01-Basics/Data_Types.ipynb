# %% [markdown]
# Data Types
# Integers
# Float
# real Numbers
# Type Casting int to float
# Boolean

# %%
float(2)
# Out:
# 2.0

# %%
int(1.1)
# Out:
# 1

# %% [markdown]
# lose data while doing float to int type casting be aware of that

# %%
int('1')
# Out:
# 1

# %%
int('A') # This will raise a ValueError
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 int('A')
#
# ValueError: invalid literal for int() with base 10: 'A'

# %%
str(1)
# Out:
# '1'

# %%
str(4.5)
# Out:
# '4.5'

# %%
int(True)
int(False)
# Out:
# 0

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False
