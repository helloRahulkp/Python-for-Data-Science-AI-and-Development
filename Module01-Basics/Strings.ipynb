# %% [markdown]
# Strings

# %%
Name = "Michael Jackson"

# %%
print(Name)
# Out:
# Michael Jackson

# %%
print(Name[1])
# Out:
# i

# %%
print(Name[1:5])
# Out:
# icha

# %%
len(Name)
# Out:
# 15

# %%
statements = Name + " is the best"

# %%
statements
# Out:
# 'Michael Jackson is the best'

# %%
print(3*Name)
# Out:
# Michael JacksonMichael JacksonMichael Jackson

# %%
print("Michael//Jackson")
# Out:
# Michael//Jackson

# %%
print(r"Michael\Jackson")
# Out:
# Michael\Jackson

# %% [markdown]
# String Methods
# Sequence methods
# String Methods

# %%
A = "Hello World"
B=A.upper()
print(B)
# Out:
# HELLO WORLD

# %%
B=A.replace("Hello","hai")
print(B)
# Out:
# hai World

# %%
A.find("o")
# Out:
# 4

# %%
print(A[4])
# Out:
# o
